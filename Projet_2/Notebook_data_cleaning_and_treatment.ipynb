# %% [markdown]
# On importe les librairies dont on aura besoin pour ce tp

# %%
import pandas as pd
from matplotlib import pyplot as plt, cm as cm

# %%
# Valeur limite des Nan acceptée
# Il faut donc moins de _VALEUR_LIMITE_NAN valeurs "NaN" pour garder la colonne
_VALEUR_LIMITE_NAN = 230000

# Référence en y du plot
_ORDONNEE = "nutrition-score-fr_100g"

# Lieu où se trouve le FICHIER
_FICHIER = 'C:\\Users\\Toni\\Desktop\\pas_synchro\\bdd.csv'

# %% [markdown]
# Fonction qui permet de selectionner des colonnes pour labase de données

# %%
def remplir_colonnes(data, nom_colonne, colonnes):
    """
        Fonction qui permets de selectionner des colonnes pour la
        base de données
    """

    # Log
    print("\nFct remplir_colonnes : Traitement de : %s" % nom_colonne)

    # test du type de la colonne. IL n'y a que les valeurs numériques qui
    # nous intéressent
    if data[nom_colonne].dtype == 'float':
        # si "100g" est trouvé dans le nom de la colonne
        if nom_colonne.find('100g') != -1 and nom_colonne.find('uk') == -1:
            colonnes.append(nom_colonne)
            print("Cette donnée est gardée")
        else:
            print("Cette donnée est exclue : pas de 100g")

    else:
        print("Cette donnée est exclue : pas un float")

# %% [markdown]
# Fonction qui supprime les valeurs absurdes

# %%
def traitement_data(data, nom_colonne):

    if nom_colonne.find('100g') > -1 and nom_colonne.find('nutrition-') == -1:

        # Log
        print("Fct traitement_data : Traitement de %s\n" % nom_colonne)

        # On garde les valeurs positives
        data = data[data[nom_colonne] >= 0]

        # Suppresion des "Nan"
        data[nom_colonne] = data[nom_colonne].dropna()

        # On prends 98% de toutes les valeurs pour couper les grandes valeurs
        # farfelues
        data = data[data[nom_colonne] < data[nom_colonne].quantile(.98)]

# %% [markdown]
# Fonction qui supprime les colonnes non nécessaires

# %%
def supprimer_colonnes(data, nom_colonne):

    # Log
    print("\nFct supprimer_colonnes : Traitement de : %s" % nom_colonne)

    # nombre de valeurs "NaN"
    cpt_nan = data[nom_colonne].isnull().sum().sum()

    # S'il y a plus de valeur "Nan" que le chiffre défini, on vire la colonne
    if cpt_nan > (_VALEUR_LIMITE_NAN):
        # Suprresion de la colonne
        del data[nom_colonne]

        # Log
        print("Cette donnée est exclue : elle contient %.0f 'NaN' " % cpt_nan)
    else:
        # Log
        print("Cette donnée est gardée : elle contient %.0f 'NaN' " % cpt_nan)

# %% [markdown]
# Fonction qui permet de compter les éléments manquants

# %%
def fct_missing_data(data):
    
    # Compte les données manquantes par colonne
    missing_data = data.isnull().sum(axis=0).reset_index()
    
    # Change les noms des colonnes
    missing_data.columns = ['column_name', 'missing_count']
    
    # Crée une nouvelle colonne et fais le calcul en pourcentage des données
    # manquantes
    missing_data['filling_factor'] = (data.shape[0]-missing_data['missing_count']) / data.shape[0] * 100
    
    # Classe et affiche
    missing_data.sort_values('filling_factor').reset_index(drop = True)

    # Affichage
    print(missing_data)

# %% [markdown]
# Fonction qui permet d'afficher les nuages de points

# %%
def affichage_plot(data, nom_colonne):

    #Log
    print("Fct affichage_plot : Affichage de la courbe\n")

    # Déliminations du visuel pour x
    xmax = max(data[nom_colonne])
    ymax = max(data[_ORDONNEE])

    # Déliminations du visuel pour y
    xmin = min(data[nom_colonne])
    ymin = min(data[_ORDONNEE])

    # création du nuage de point avec toujours la même ordonnée
    data.plot(kind="scatter", x=nom_colonne, y=_ORDONNEE)

    # Affichage
    plt.grid(True)
    plt.xlim(xmin, xmax)
    plt.ylim(ymin, ymax)
    plt.show()

# %% [markdown]
# A partir de ce point, on est dans le main()

# %%
# Définition de la variable qui récupère le nom des colonnes
colonnes = []

# %%
# On charge la première ligne du dataset
bdd_titres = pd.read_csv(_FICHIER,
                             nrows=1,
                             error_bad_lines=False,
                             engine='python',
                             sep=r'\t')

# %%
# Fonction qui va choisir les colonnes à récupérer suivant les crières
# définis
for i in bdd_titres:
    remplir_colonnes(bdd_titres, i, colonnes)
# Out:
# Fct remplir_colonnes : Traitement de : "code
# Cette donnée est exclue : pas un float
#
# Fct remplir_colonnes : Traitement de : url
# Cette donnée est exclue : pas un float
#
# Fct remplir_colonnes : Traitement de : creator
# Cette donnée est exclue : pas un float
#
# Fct remplir_colonnes : Traitement de : created_t
# Cette donnée est exclue : pas un float
#
# Fct remplir_colonnes : Traitement de : created_datetime
# Cette donnée est exclue : pas un float
#
# Fct remplir_colonnes : Traitement de : last_modified_t
# Cette donnée est exclue : pas un float
#
# Fct remplir_colonnes : Traitement de : last_modified_datetime
# Cette donnée est exclue : pas un float
#
# Fct remplir_colonnes : Traitement de : product_name
# Cette donnée est exclue : pas un float
#
# Fct remplir_colonnes : Traitement de : generic_name
# Cette donnée est exclue : pas de 100g
#
# Fct remplir_colonnes : Traitement de : quantity
# Cette donnée est exclue : pas un float
#
# Fct remplir_colonnes : Traitement de : packaging
# Cette donnée est exclue : pas de 100g
#
# Fct remplir_colonnes : Traitement de : packaging_tags
# Cette donnée est exclue : pas de 100g
#
# Fct remplir_colonnes : Traitement de : brands
# Cette donnée est exclue : pas un float
#
# Fct remplir_colonnes : Traitement de : brands_tags
# Cette donnée est exclue : pas un float
#
# Fct remplir_colonnes : Traitement de : categories
# Cette donnée est exclue : pas de 100g
#
# Fct remplir_colonnes : Traitement de : categories_tags
# Cette donnée est exclue : pas de 100g
#
# Fct remplir_colonnes : Traitement de : categories_fr
# Cette donnée est exclue : pas de 100g
#
# Fct remplir_colonnes : Traitement de : origins
# Cette donnée est exclue : pas de 100g
#
# Fct remplir_colonnes : Traitement de : origins_tags
# Cette donnée est exclue : pas de 100g
#
# Fct remplir_colonnes : Traitement de : manufacturing_places
# Cette donnée est exclue : pas de 100g
#
# Fct remplir_colonnes : Traitement de : manufacturing_places_tags
# Cette donnée est exclue : pas de 100g
#
# Fct remplir_colonnes : Traitement de : labels
# Cette donnée est exclue : pas de 100g
#
# Fct remplir_colonnes : Traitement de : labels_tags
# Cette donnée est exclue : pas de 100g
#
# Fct remplir_colonnes : Traitement de : labels_fr
# Cette donnée est exclue : pas de 100g
#
# Fct remplir_colonnes : Traitement de : emb_codes
# Cette donnée est exclue : pas de 100g
#
# Fct remplir_colonnes : Traitement de : emb_codes_tags
# Cette donnée est exclue : pas de 100g
#
# Fct remplir_colonnes : Traitement de : first_packaging_code_geo
# Cette donnée est exclue : pas de 100g
#
# Fct remplir_colonnes : Traitement de : cities
# Cette donnée est exclue : pas de 100g
#
# Fct remplir_colonnes : Traitement de : cities_tags
# Cette donnée est exclue : pas de 100g
#
# Fct remplir_colonnes : Traitement de : purchase_places
# Cette donnée est exclue : pas de 100g
#
# Fct remplir_colonnes : Traitement de : stores
# Cette donnée est exclue : pas de 100g
#
# Fct remplir_colonnes : Traitement de : countries
# Cette donnée est exclue : pas un float
#
# Fct remplir_colonnes : Traitement de : countries_tags
# Cette donnée est exclue : pas un float
#
# Fct remplir_colonnes : Traitement de : countries_fr
# Cette donnée est exclue : pas un float
#
# Fct remplir_colonnes : Traitement de : ingredients_text
# Cette donnée est exclue : pas de 100g
#
# Fct remplir_colonnes : Traitement de : allergens
# Cette donnée est exclue : pas de 100g
#
# Fct remplir_colonnes : Traitement de : allergens_fr
# Cette donnée est exclue : pas de 100g
#
# Fct remplir_colonnes : Traitement de : traces
# Cette donnée est exclue : pas de 100g
#
# Fct remplir_colonnes : Traitement de : traces_tags
# Cette donnée est exclue : pas de 100g
#
# Fct remplir_colonnes : Traitement de : traces_fr
# Cette donnée est exclue : pas de 100g
#
# Fct remplir_colonnes : Traitement de : serving_size
# Cette donnée est exclue : pas de 100g
#
# Fct remplir_colonnes : Traitement de : no_nutriments
# Cette donnée est exclue : pas de 100g
#
# Fct remplir_colonnes : Traitement de : additives_n
# Cette donnée est exclue : pas de 100g
#
# Fct remplir_colonnes : Traitement de : additives
# Cette donnée est exclue : pas de 100g
#
# Fct remplir_colonnes : Traitement de : additives_tags
# Cette donnée est exclue : pas de 100g
#
# Fct remplir_colonnes : Traitement de : additives_fr
# Cette donnée est exclue : pas de 100g
#
# Fct remplir_colonnes : Traitement de : ingredients_from_palm_oil_n
# Cette donnée est exclue : pas de 100g
#
# Fct remplir_colonnes : Traitement de : ingredients_from_palm_oil
# Cette donnée est exclue : pas de 100g
#
# Fct remplir_colonnes : Traitement de : ingredients_from_palm_oil_tags
# Cette donnée est exclue : pas de 100g
#
# Fct remplir_colonnes : Traitement de : ingredients_that_may_be_from_palm_oil_n
# Cette donnée est exclue : pas de 100g
#
# Fct remplir_colonnes : Traitement de : ingredients_that_may_be_from_palm_oil
# Cette donnée est exclue : pas de 100g
#
# Fct remplir_colonnes : Traitement de : ingredients_that_may_be_from_palm_oil_tags
# Cette donnée est exclue : pas de 100g
#
# Fct remplir_colonnes : Traitement de : nutrition_grade_uk
# Cette donnée est exclue : pas de 100g
#
# Fct remplir_colonnes : Traitement de : nutrition_grade_fr
# Cette donnée est exclue : pas de 100g
#
# Fct remplir_colonnes : Traitement de : pnns_groups_1
# Cette donnée est exclue : pas de 100g
#
# Fct remplir_colonnes : Traitement de : pnns_groups_2
# Cette donnée est exclue : pas de 100g
#
# Fct remplir_colonnes : Traitement de : states
# Cette donnée est exclue : pas un float
#
# Fct remplir_colonnes : Traitement de : states_tags
# Cette donnée est exclue : pas un float
#
# Fct remplir_colonnes : Traitement de : states_fr
# Cette donnée est exclue : pas un float
#
# Fct remplir_colonnes : Traitement de : main_category
# Cette donnée est exclue : pas de 100g
#
# Fct remplir_colonnes : Traitement de : main_category_fr
# Cette donnée est exclue : pas de 100g
#
# Fct remplir_colonnes : Traitement de : image_url
# Cette donnée est exclue : pas de 100g
#
# Fct remplir_colonnes : Traitement de : image_small_url
# Cette donnée est exclue : pas de 100g
#
# Fct remplir_colonnes : Traitement de : energy_100g
# Cette donnée est gardée
#
# Fct remplir_colonnes : Traitement de : energy-from-fat_100g
# Cette donnée est gardée
#
# Fct remplir_colonnes : Traitement de : fat_100g
# Cette donnée est gardée
#
# Fct remplir_colonnes : Traitement de : saturated-fat_100g
# Cette donnée est gardée
#
# Fct remplir_colonnes : Traitement de : butyric-acid_100g
# Cette donnée est gardée
#
# Fct remplir_colonnes : Traitement de : caproic-acid_100g
# Cette donnée est gardée
#
# Fct remplir_colonnes : Traitement de : caprylic-acid_100g
# Cette donnée est gardée
#
# Fct remplir_colonnes : Traitement de : capric-acid_100g
# Cette donnée est gardée
#
# Fct remplir_colonnes : Traitement de : lauric-acid_100g
# Cette donnée est gardée
#
# Fct remplir_colonnes : Traitement de : myristic-acid_100g
# Cette donnée est gardée
#
# Fct remplir_colonnes : Traitement de : palmitic-acid_100g
# Cette donnée est gardée
#
# Fct remplir_colonnes : Traitement de : stearic-acid_100g
# Cette donnée est gardée
#
# Fct remplir_colonnes : Traitement de : arachidic-acid_100g
# Cette donnée est gardée
#
# Fct remplir_colonnes : Traitement de : behenic-acid_100g
# Cette donnée est gardée
#
# Fct remplir_colonnes : Traitement de : lignoceric-acid_100g
# Cette donnée est gardée
#
# Fct remplir_colonnes : Traitement de : cerotic-acid_100g
# Cette donnée est gardée
#
# Fct remplir_colonnes : Traitement de : montanic-acid_100g
# Cette donnée est gardée
#
# Fct remplir_colonnes : Traitement de : melissic-acid_100g
# Cette donnée est gardée
#
# Fct remplir_colonnes : Traitement de : monounsaturated-fat_100g
# Cette donnée est gardée
#
# Fct remplir_colonnes : Traitement de : polyunsaturated-fat_100g
# Cette donnée est gardée
#
# Fct remplir_colonnes : Traitement de : omega-3-fat_100g
# Cette donnée est gardée
#
# Fct remplir_colonnes : Traitement de : alpha-linolenic-acid_100g
# Cette donnée est gardée
#
# Fct remplir_colonnes : Traitement de : eicosapentaenoic-acid_100g
# Cette donnée est gardée
#
# Fct remplir_colonnes : Traitement de : docosahexaenoic-acid_100g
# Cette donnée est gardée
#
# Fct remplir_colonnes : Traitement de : omega-6-fat_100g
# Cette donnée est gardée
#
# Fct remplir_colonnes : Traitement de : linoleic-acid_100g
# Cette donnée est gardée
#
# Fct remplir_colonnes : Traitement de : arachidonic-acid_100g
# Cette donnée est gardée
#
# Fct remplir_colonnes : Traitement de : gamma-linolenic-acid_100g
# Cette donnée est gardée
#
# Fct remplir_colonnes : Traitement de : dihomo-gamma-linolenic-acid_100g
# Cette donnée est gardée
#
# Fct remplir_colonnes : Traitement de : omega-9-fat_100g
# Cette donnée est gardée
#
# Fct remplir_colonnes : Traitement de : oleic-acid_100g
# Cette donnée est gardée
#
# Fct remplir_colonnes : Traitement de : elaidic-acid_100g
# Cette donnée est gardée
#
# Fct remplir_colonnes : Traitement de : gondoic-acid_100g
# Cette donnée est gardée
#
# Fct remplir_colonnes : Traitement de : mead-acid_100g
# Cette donnée est gardée
#
# Fct remplir_colonnes : Traitement de : erucic-acid_100g
# Cette donnée est gardée
#
# Fct remplir_colonnes : Traitement de : nervonic-acid_100g
# Cette donnée est gardée
#
# Fct remplir_colonnes : Traitement de : trans-fat_100g
# Cette donnée est gardée
#
# Fct remplir_colonnes : Traitement de : cholesterol_100g
# Cette donnée est gardée
#
# Fct remplir_colonnes : Traitement de : carbohydrates_100g
# Cette donnée est gardée
#
# Fct remplir_colonnes : Traitement de : sugars_100g
# Cette donnée est gardée
#
# Fct remplir_colonnes : Traitement de : sucrose_100g
# Cette donnée est gardée
#
# Fct remplir_colonnes : Traitement de : glucose_100g
# Cette donnée est gardée
#
# Fct remplir_colonnes : Traitement de : fructose_100g
# Cette donnée est gardée
#
# Fct remplir_colonnes : Traitement de : lactose_100g
# Cette donnée est gardée
#
# Fct remplir_colonnes : Traitement de : maltose_100g
# Cette donnée est gardée
#
# Fct remplir_colonnes : Traitement de : maltodextrins_100g
# Cette donnée est gardée
#
# Fct remplir_colonnes : Traitement de : starch_100g
# Cette donnée est gardée
#
# Fct remplir_colonnes : Traitement de : polyols_100g
# Cette donnée est gardée
#
# Fct remplir_colonnes : Traitement de : fiber_100g
# Cette donnée est gardée
#
# Fct remplir_colonnes : Traitement de : proteins_100g
# Cette donnée est gardée
#
# Fct remplir_colonnes : Traitement de : casein_100g
# Cette donnée est gardée
#
# Fct remplir_colonnes : Traitement de : serum-proteins_100g
# Cette donnée est gardée
#
# Fct remplir_colonnes : Traitement de : nucleotides_100g
# Cette donnée est gardée
#
# Fct remplir_colonnes : Traitement de : salt_100g
# Cette donnée est gardée
#
# Fct remplir_colonnes : Traitement de : sodium_100g
# Cette donnée est gardée
#
# Fct remplir_colonnes : Traitement de : alcohol_100g
# Cette donnée est gardée
#
# Fct remplir_colonnes : Traitement de : vitamin-a_100g
# Cette donnée est gardée
#
# Fct remplir_colonnes : Traitement de : beta-carotene_100g
# Cette donnée est gardée
#
# Fct remplir_colonnes : Traitement de : vitamin-d_100g
# Cette donnée est gardée
#
# Fct remplir_colonnes : Traitement de : vitamin-e_100g
# Cette donnée est gardée
#
# Fct remplir_colonnes : Traitement de : vitamin-k_100g
# Cette donnée est gardée
#
# Fct remplir_colonnes : Traitement de : vitamin-c_100g
# Cette donnée est gardée
#
# Fct remplir_colonnes : Traitement de : vitamin-b1_100g
# Cette donnée est gardée
#
# Fct remplir_colonnes : Traitement de : vitamin-b2_100g
# Cette donnée est gardée
#
# Fct remplir_colonnes : Traitement de : vitamin-pp_100g
# Cette donnée est gardée
#
# Fct remplir_colonnes : Traitement de : vitamin-b6_100g
# Cette donnée est gardée
#
# Fct remplir_colonnes : Traitement de : vitamin-b9_100g
# Cette donnée est gardée
#
# Fct remplir_colonnes : Traitement de : folates_100g
# Cette donnée est gardée
#
# Fct remplir_colonnes : Traitement de : vitamin-b12_100g
# Cette donnée est gardée
#
# Fct remplir_colonnes : Traitement de : biotin_100g
# Cette donnée est gardée
#
# Fct remplir_colonnes : Traitement de : pantothenic-acid_100g
# Cette donnée est gardée
#
# Fct remplir_colonnes : Traitement de : silica_100g
# Cette donnée est gardée
#
# Fct remplir_colonnes : Traitement de : bicarbonate_100g
# Cette donnée est gardée
#
# Fct remplir_colonnes : Traitement de : potassium_100g
# Cette donnée est gardée
#
# Fct remplir_colonnes : Traitement de : chloride_100g
# Cette donnée est gardée
#
# Fct remplir_colonnes : Traitement de : calcium_100g
# Cette donnée est gardée
#
# Fct remplir_colonnes : Traitement de : phosphorus_100g
# Cette donnée est gardée
#
# Fct remplir_colonnes : Traitement de : iron_100g
# Cette donnée est gardée
#
# Fct remplir_colonnes : Traitement de : magnesium_100g
# Cette donnée est gardée
#
# Fct remplir_colonnes : Traitement de : zinc_100g
# Cette donnée est gardée
#
# Fct remplir_colonnes : Traitement de : copper_100g
# Cette donnée est gardée
#
# Fct remplir_colonnes : Traitement de : manganese_100g
# Cette donnée est gardée
#
# Fct remplir_colonnes : Traitement de : fluoride_100g
# Cette donnée est gardée
#
# Fct remplir_colonnes : Traitement de : selenium_100g
# Cette donnée est gardée
#
# Fct remplir_colonnes : Traitement de : chromium_100g
# Cette donnée est gardée
#
# Fct remplir_colonnes : Traitement de : molybdenum_100g
# Cette donnée est gardée
#
# Fct remplir_colonnes : Traitement de : iodine_100g
# Cette donnée est gardée
#
# Fct remplir_colonnes : Traitement de : caffeine_100g
# Cette donnée est gardée
#
# Fct remplir_colonnes : Traitement de : taurine_100g
# Cette donnée est gardée
#
# Fct remplir_colonnes : Traitement de : ph_100g
# Cette donnée est gardée
#
# Fct remplir_colonnes : Traitement de : fruits-vegetables-nuts_100g
# Cette donnée est gardée
#
# Fct remplir_colonnes : Traitement de : collagen-meat-protein-ratio_100g
# Cette donnée est gardée
#
# Fct remplir_colonnes : Traitement de : cocoa_100g
# Cette donnée est gardée
#
# Fct remplir_colonnes : Traitement de : chlorophyl_100g
# Cette donnée est gardée
#
# Fct remplir_colonnes : Traitement de : carbon-footprint_100g
# Cette donnée est gardée
#
# Fct remplir_colonnes : Traitement de : nutrition-score-fr_100g
# Cette donnée est gardée
#
# Fct remplir_colonnes : Traitement de : nutrition-score-uk_100g
# Cette donnée est exclue : pas de 100g
#
# Fct remplir_colonnes : Traitement de : glycemic-index_100g
# Cette donnée est gardée
#
# Fct remplir_colonnes : Traitement de : water-hardness_100g";;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;
# Cette donnée est exclue : pas un float

# %%
# On charge le dataset sur les colonnes qui nous ont intéressés dans la
# fonction du dessus
data = pd.read_csv(_FICHIER,
                   usecols=colonnes,
                   error_bad_lines=False,
                   engine='python',
                   sep=r'\t')

# %%
# On supprime les lignes qui sont vides et n'ont que des "nan"
# axis : {0 or ‘index’, 1 or ‘columns’},
data = data.dropna(axis=1, how='all')
data = data.dropna(how='all')

# %%
# Suppression des colonnes qui ne remplissent pas les conditions posées
for i in data:
    supprimer_colonnes(data, i)
# Out:
# Fct supprimer_colonnes : Traitement de : energy_100g
# Cette donnée est gardée : elle contient 4351 'NaN'
#
# Fct supprimer_colonnes : Traitement de : energy-from-fat_100g
# Cette donnée est exclue : elle contient 264584 'NaN'
#
# Fct supprimer_colonnes : Traitement de : fat_100g
# Cette donnée est gardée : elle contient 21569 'NaN'
#
# Fct supprimer_colonnes : Traitement de : saturated-fat_100g
# Cette donnée est gardée : elle contient 35905 'NaN'
#
# Fct supprimer_colonnes : Traitement de : caproic-acid_100g
# Cette donnée est exclue : elle contient 265435 'NaN'
#
# Fct supprimer_colonnes : Traitement de : caprylic-acid_100g
# Cette donnée est exclue : elle contient 265429 'NaN'
#
# Fct supprimer_colonnes : Traitement de : capric-acid_100g
# Cette donnée est exclue : elle contient 265439 'NaN'
#
# Fct supprimer_colonnes : Traitement de : lauric-acid_100g
# Cette donnée est exclue : elle contient 265437 'NaN'
#
# Fct supprimer_colonnes : Traitement de : myristic-acid_100g
# Cette donnée est exclue : elle contient 265440 'NaN'
#
# Fct supprimer_colonnes : Traitement de : palmitic-acid_100g
# Cette donnée est exclue : elle contient 265429 'NaN'
#
# Fct supprimer_colonnes : Traitement de : stearic-acid_100g
# Cette donnée est exclue : elle contient 265429 'NaN'
#
# Fct supprimer_colonnes : Traitement de : arachidic-acid_100g
# Cette donnée est exclue : elle contient 265417 'NaN'
#
# Fct supprimer_colonnes : Traitement de : behenic-acid_100g
# Cette donnée est exclue : elle contient 265418 'NaN'
#
# Fct supprimer_colonnes : Traitement de : montanic-acid_100g
# Cette donnée est exclue : elle contient 265440 'NaN'
#
# Fct supprimer_colonnes : Traitement de : monounsaturated-fat_100g
# Cette donnée est exclue : elle contient 242618 'NaN'
#
# Fct supprimer_colonnes : Traitement de : polyunsaturated-fat_100g
# Cette donnée est exclue : elle contient 242582 'NaN'
#
# Fct supprimer_colonnes : Traitement de : omega-3-fat_100g
# Cette donnée est exclue : elle contient 264600 'NaN'
#
# Fct supprimer_colonnes : Traitement de : alpha-linolenic-acid_100g
# Cette donnée est exclue : elle contient 265255 'NaN'
#
# Fct supprimer_colonnes : Traitement de : eicosapentaenoic-acid_100g
# Cette donnée est exclue : elle contient 265403 'NaN'
#
# Fct supprimer_colonnes : Traitement de : docosahexaenoic-acid_100g
# Cette donnée est exclue : elle contient 265363 'NaN'
#
# Fct supprimer_colonnes : Traitement de : omega-6-fat_100g
# Cette donnée est exclue : elle contient 265253 'NaN'
#
# Fct supprimer_colonnes : Traitement de : linoleic-acid_100g
# Cette donnée est exclue : elle contient 265292 'NaN'
#
# Fct supprimer_colonnes : Traitement de : arachidonic-acid_100g
# Cette donnée est exclue : elle contient 265433 'NaN'
#
# Fct supprimer_colonnes : Traitement de : gamma-linolenic-acid_100g
# Cette donnée est exclue : elle contient 265417 'NaN'
#
# Fct supprimer_colonnes : Traitement de : dihomo-gamma-linolenic-acid_100g
# Cette donnée est exclue : elle contient 265418 'NaN'
#
# Fct supprimer_colonnes : Traitement de : omega-9-fat_100g
# Cette donnée est exclue : elle contient 265420 'NaN'
#
# Fct supprimer_colonnes : Traitement de : oleic-acid_100g
# Cette donnée est exclue : elle contient 265428 'NaN'
#
# Fct supprimer_colonnes : Traitement de : gondoic-acid_100g
# Cette donnée est exclue : elle contient 265427 'NaN'
#
# Fct supprimer_colonnes : Traitement de : trans-fat_100g
# Cette donnée est gardée : elle contient 122143 'NaN'
#
# Fct supprimer_colonnes : Traitement de : cholesterol_100g
# Cette donnée est gardée : elle contient 121351 'NaN'
#
# Fct supprimer_colonnes : Traitement de : carbohydrates_100g
# Cette donnée est gardée : elle contient 21876 'NaN'
#
# Fct supprimer_colonnes : Traitement de : sugars_100g
# Cette donnée est gardée : elle contient 20488 'NaN'
#
# Fct supprimer_colonnes : Traitement de : sucrose_100g
# Cette donnée est exclue : elle contient 265369 'NaN'
#
# Fct supprimer_colonnes : Traitement de : glucose_100g
# Cette donnée est exclue : elle contient 265415 'NaN'
#
# Fct supprimer_colonnes : Traitement de : fructose_100g
# Cette donnée est exclue : elle contient 265403 'NaN'
#
# Fct supprimer_colonnes : Traitement de : lactose_100g
# Cette donnée est exclue : elle contient 265179 'NaN'
#
# Fct supprimer_colonnes : Traitement de : maltose_100g
# Cette donnée est exclue : elle contient 265437 'NaN'
#
# Fct supprimer_colonnes : Traitement de : maltodextrins_100g
# Cette donnée est exclue : elle contient 265430 'NaN'
#
# Fct supprimer_colonnes : Traitement de : starch_100g
# Cette donnée est exclue : elle contient 265175 'NaN'
#
# Fct supprimer_colonnes : Traitement de : polyols_100g
# Cette donnée est exclue : elle contient 265022 'NaN'
#
# Fct supprimer_colonnes : Traitement de : fiber_100g
# Cette donnée est gardée : elle contient 64565 'NaN'
#
# Fct supprimer_colonnes : Traitement de : proteins_100g
# Cette donnée est gardée : elle contient 5538 'NaN'
#
# Fct supprimer_colonnes : Traitement de : casein_100g
# Cette donnée est exclue : elle contient 265414 'NaN'
#
# Fct supprimer_colonnes : Traitement de : serum-proteins_100g
# Cette donnée est exclue : elle contient 265425 'NaN'
#
# Fct supprimer_colonnes : Traitement de : nucleotides_100g
# Cette donnée est exclue : elle contient 265421 'NaN'
#
# Fct supprimer_colonnes : Traitement de : salt_100g
# Cette donnée est gardée : elle contient 9939 'NaN'
#
# Fct supprimer_colonnes : Traitement de : sodium_100g
# Cette donnée est gardée : elle contient 9997 'NaN'
#
# Fct supprimer_colonnes : Traitement de : alcohol_100g
# Cette donnée est exclue : elle contient 261296 'NaN'
#
# Fct supprimer_colonnes : Traitement de : vitamin-a_100g
# Cette donnée est gardée : elle contient 127887 'NaN'
#
# Fct supprimer_colonnes : Traitement de : beta-carotene_100g
# Cette donnée est exclue : elle contient 265408 'NaN'
#
# Fct supprimer_colonnes : Traitement de : vitamin-d_100g
# Cette donnée est exclue : elle contient 258384 'NaN'
#
# Fct supprimer_colonnes : Traitement de : vitamin-e_100g
# Cette donnée est exclue : elle contient 264100 'NaN'
#
# Fct supprimer_colonnes : Traitement de : vitamin-k_100g
# Cette donnée est exclue : elle contient 264523 'NaN'
#
# Fct supprimer_colonnes : Traitement de : vitamin-c_100g
# Cette donnée est gardée : elle contient 124575 'NaN'
#
# Fct supprimer_colonnes : Traitement de : vitamin-b1_100g
# Cette donnée est exclue : elle contient 254287 'NaN'
#
# Fct supprimer_colonnes : Traitement de : vitamin-b2_100g
# Cette donnée est exclue : elle contient 254626 'NaN'
#
# Fct supprimer_colonnes : Traitement de : vitamin-pp_100g
# Cette donnée est exclue : elle contient 253712 'NaN'
#
# Fct supprimer_colonnes : Traitement de : vitamin-b6_100g
# Cette donnée est exclue : elle contient 258657 'NaN'
#
# Fct supprimer_colonnes : Traitement de : vitamin-b9_100g
# Cette donnée est exclue : elle contient 260201 'NaN'
#
# Fct supprimer_colonnes : Traitement de : folates_100g
# Cette donnée est exclue : elle contient 262399 'NaN'
#
# Fct supprimer_colonnes : Traitement de : vitamin-b12_100g
# Cette donnée est exclue : elle contient 260141 'NaN'
#
# Fct supprimer_colonnes : Traitement de : biotin_100g
# Cette donnée est exclue : elle contient 265111 'NaN'
#
# Fct supprimer_colonnes : Traitement de : pantothenic-acid_100g
# Cette donnée est exclue : elle contient 262958 'NaN'
#
# Fct supprimer_colonnes : Traitement de : silica_100g
# Cette donnée est exclue : elle contient 265403 'NaN'
#
# Fct supprimer_colonnes : Traitement de : bicarbonate_100g
# Cette donnée est exclue : elle contient 265337 'NaN'
#
# Fct supprimer_colonnes : Traitement de : potassium_100g
# Cette donnée est exclue : elle contient 240694 'NaN'
#
# Fct supprimer_colonnes : Traitement de : chloride_100g
# Cette donnée est exclue : elle contient 265283 'NaN'
#
# Fct supprimer_colonnes : Traitement de : calcium_100g
# Cette donnée est gardée : elle contient 124392 'NaN'
#
# Fct supprimer_colonnes : Traitement de : phosphorus_100g
# Cette donnée est exclue : elle contient 259596 'NaN'
#
# Fct supprimer_colonnes : Traitement de : iron_100g
# Cette donnée est gardée : elle contient 124979 'NaN'
#
# Fct supprimer_colonnes : Traitement de : magnesium_100g
# Cette donnée est exclue : elle contient 259188 'NaN'
#
# Fct supprimer_colonnes : Traitement de : zinc_100g
# Cette donnée est exclue : elle contient 261512 'NaN'
#
# Fct supprimer_colonnes : Traitement de : copper_100g
# Cette donnée est exclue : elle contient 263335 'NaN'
#
# Fct supprimer_colonnes : Traitement de : manganese_100g
# Cette donnée est exclue : elle contient 263821 'NaN'
#
# Fct supprimer_colonnes : Traitement de : fluoride_100g
# Cette donnée est exclue : elle contient 265362 'NaN'
# Fct supprimer_colonnes : Traitement de : selenium_100g
# Cette donnée est exclue : elle contient 264273 'NaN'
#
# Fct supprimer_colonnes : Traitement de : chromium_100g
# Cette donnée est exclue : elle contient 265421 'NaN'
#
# Fct supprimer_colonnes : Traitement de : molybdenum_100g
# Cette donnée est exclue : elle contient 265430 'NaN'
#
# Fct supprimer_colonnes : Traitement de : iodine_100g
# Cette donnée est exclue : elle contient 265182 'NaN'
#
# Fct supprimer_colonnes : Traitement de : caffeine_100g
# Cette donnée est exclue : elle contient 265363 'NaN'
#
# Fct supprimer_colonnes : Traitement de : taurine_100g
# Cette donnée est exclue : elle contient 265412 'NaN'
#
# Fct supprimer_colonnes : Traitement de : ph_100g
# Cette donnée est exclue : elle contient 265392 'NaN'
#
# Fct supprimer_colonnes : Traitement de : fruits-vegetables-nuts_100g
# Cette donnée est exclue : elle contient 262414 'NaN'
#
# Fct supprimer_colonnes : Traitement de : collagen-meat-protein-ratio_100g
# Cette donnée est exclue : elle contient 265276 'NaN'
#
# Fct supprimer_colonnes : Traitement de : cocoa_100g
# Cette donnée est exclue : elle contient 264493 'NaN'
#
# Fct supprimer_colonnes : Traitement de : carbon-footprint_100g
# Cette donnée est exclue : elle contient 265173 'NaN'
#
# Fct supprimer_colonnes : Traitement de : nutrition-score-fr_100g
# Cette donnée est gardée : elle contient 44250 'NaN'

# %%
# Trouver le numéro de colonne qui nous sert d'ordonné dans l'affichage
position_ordonne = data.columns.get_loc(_ORDONNEE)

# Affichage des nuages de points avant traitement
for i in data.columns.values[0:position_ordonne]:
    # Log
    print("Avant traitement")
    affichage_plot(data, i)
# Out:
# Avant traitement
# Fct affichage_plot : Affichage de la courbe
# Avant traitement
# Fct affichage_plot : Affichage de la courbe
# Avant traitement
# Fct affichage_plot : Affichage de la courbe
# Avant traitement
# Fct affichage_plot : Affichage de la courbe
# Avant traitement
# Fct affichage_plot : Affichage de la courbe
# Avant traitement
# Fct affichage_plot : Affichage de la courbe
# Avant traitement
# Fct affichage_plot : Affichage de la courbe
# Avant traitement
# Fct affichage_plot : Affichage de la courbe
# Avant traitement
# Fct affichage_plot : Affichage de la courbe
# Avant traitement
# Fct affichage_plot : Affichage de la courbe
# Avant traitement
# Fct affichage_plot : Affichage de la courbe
# Avant traitement
# Fct affichage_plot : Affichage de la courbe
# Avant traitement
# Fct affichage_plot : Affichage de la courbe
# Avant traitement
# Fct affichage_plot : Affichage de la courbe
# Avant traitement
# Fct affichage_plot : Affichage de la courbe

# %%
# Log
print("Fct traitement_data : \n")

for nom_colonne in data.columns.values[0:position_ordonne]:
    # On garde les valeurs positives
    data = data[data[nom_colonne] >= 0]
    # On prends 98% de toutes les valeurs pour couper les grandes valeurs
    # farfelues
    data = data[data[nom_colonne] <= data[nom_colonne].quantile(0.98)]
    # Replace missing values with the mean if necessary
    #data = data.fillna(0)
# Out:
# Fct traitement_data :

# %%
# Affichage des nuages de points après traitement
for i in data.columns.values[0:position_ordonne]:
    # Log
    print("Après traitement")
    affichage_plot(data, i)

print("\n\nLa base de données est nettoyée.\n\n")
# Out:
# Après traitement
# Fct affichage_plot : Affichage de la courbe
# Après traitement
# Fct affichage_plot : Affichage de la courbe
# Après traitement
# Fct affichage_plot : Affichage de la courbe
# Après traitement
# Fct affichage_plot : Affichage de la courbe
# Après traitement
# Fct affichage_plot : Affichage de la courbe
# Après traitement
# Fct affichage_plot : Affichage de la courbe
# Après traitement
# Fct affichage_plot : Affichage de la courbe
# Après traitement
# Fct affichage_plot : Affichage de la courbe
# Après traitement
# Fct affichage_plot : Affichage de la courbe
# Après traitement
# Fct affichage_plot : Affichage de la courbe
# Après traitement
# Fct affichage_plot : Affichage de la courbe
# Après traitement
# Fct affichage_plot : Affichage de la courbe
# Après traitement
# Fct affichage_plot : Affichage de la courbe
# Après traitement
# Fct affichage_plot : Affichage de la courbe
# Après traitement
# Fct affichage_plot : Affichage de la courbe
# La base de données est nettoyée.

# %%
# Appel de le fonction qui va montrer les données manquantes
fct_missing_data(data)
# Out:
#                 column_name  missing_count  filling_factor
# 0               energy_100g              0           100.0
# 1                  fat_100g              0           100.0
# 2        saturated-fat_100g              0           100.0
# 3            trans-fat_100g              0           100.0
# 4          cholesterol_100g              0           100.0
# 5        carbohydrates_100g              0           100.0
# 6               sugars_100g              0           100.0
# 7                fiber_100g              0           100.0
# 8             proteins_100g              0           100.0
# 9                 salt_100g              0           100.0
# 10              sodium_100g              0           100.0
# 11           vitamin-a_100g              0           100.0
# 12           vitamin-c_100g              0           100.0
# 13             calcium_100g              0           100.0
# 14                iron_100g              0           100.0
# 15  nutrition-score-fr_100g              0           100.0

# %%
# export de la database cleanée dans un csv
data.to_csv('C:\\Users\\Toni\\Desktop\\pas_synchro\\bdd_clean.csv')
